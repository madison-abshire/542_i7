# %%
import requests

print(requests.get('https://result-squall-sanction.ngrok-free.dev/data/stations/future').text)
# Out:
# ["NE 130th Station","Shoreline Station","Mountlake Terrace Station","Lynnwood Station","220th St SW Station","Downtown Redmond Station","SE Redmond Station","Graham St Station","Boeing Access Rd","Delrdige Station (DEL-5, DEL-6)","Avalon Station (WSJ-5)","Denny Station (DT-2)","Stadium Station (CID-1a)","Midtown Station (DT-1)","Westlake Station (DT-1)","South Lake Union Station (DT-1)","Seattle Center Station (DT-1)","Smith Cove Station (SIB-1)","IBB-1a Interbay Station","Ballard Station (IBB-1a, IBB-1b)","Alaska Junction Station (WSJ-3a, WSJ-5)","SODO Station (WS SODO-1a Staggered)"]
